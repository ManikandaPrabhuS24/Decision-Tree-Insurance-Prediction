# %%
#Medical Insurance Cost Prediction using Decision Tree Regression

#Author: Manikandaprabhu.S  
#Objective: To build a Decision Tree Regression model to predict medical insurance costs based on demographic and health-related features.

# %%
## 1. Importing Required Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
## 2. Loading the Dataset
dataset = pd.read_csv("insurance_pre.csv")
pd.options.display.max_rows = 10
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
## 3. Data Preprocessing (Handling Categorical Variables)
data = pd.get_dummies(dataset,dtype=int)
data
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 1333           0
# 1334           0
# 1335           0
# 1336           0
# 1337           1
#
# [1338 rows x 8 columns]

# %%
## 4. Exploratory Data Inspection
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         1338 non-null   int64
#  1   bmi         1338 non-null   float64
#  2   children    1338 non-null   int64
#  3   charges     1338 non-null   float64
#  4   sex_female  1338 non-null   int64
#  5   sex_male    1338 non-null   int64
#  6   smoker_no   1338 non-null   int64
#  7   smoker_yes  1338 non-null   int64
# dtypes: float64(2), int64(6)
# memory usage: 83.8 KB

# %%
data.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male',
#        'smoker_no', 'smoker_yes'],
#       dtype='object')

# %%
## 5. Preparing Features and Target Variable
Features = data[['age', 'bmi', 'children','sex_male','smoker_yes']]
Target = data[['charges']].values.ravel()
Features
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
## 6. Splitting Dataset into Training and Testing Sets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(Features,Target,test_size=1/3,random_state=0)
x_train
# Out:
#       age    bmi  children  sex_male  smoker_yes
# 482    18  31.35         0         0           0
# 338    50  32.30         1         1           1
# 356    46  43.89         3         1           0
# 869    25  24.30         3         0           0
# 182    22  19.95         3         1           0
# ...   ...    ...       ...       ...         ...
# 763    27  26.03         0         1           0
# 835    42  35.97         2         1           0
# 1216   40  25.08         0         1           0
# 559    19  35.53         0         1           0
# 684    33  18.50         1         0           0
#
# [892 rows x 5 columns]

# %%
## 7. Feature Scaling (Important for Decision Tree)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_test
# Out:
# array([[ 0.89108031, -0.07576237, -0.0755796 ,  1.01127431, -0.49929923],
#        [ 0.5336223 , -0.21009861, -0.0755796 , -0.98885138, -0.49929923],
#        [ 0.6051139 ,  1.60182214,  0.75672907,  1.01127431,  2.00280702],
#        ...,
#        [-1.46814257,  0.65256665,  0.75672907, -0.98885138,  2.00280702],
#        [-0.82471815,  0.37742013,  1.58903774,  1.01127431, -0.49929923],
#        [ 0.89108031,  1.24817794,  0.75672907, -0.98885138, -0.49929923]],
#       shape=(446, 5))

# %%
## 8. Training Decision Tree Model with Hyperparameter Tuning (GridSearchCV)
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion': ['squared_error', 'absolute_error', 'friedman_mse'],'max_features': ['sqrt', 'log2', None],'splitter': ['best', 'random'],'max_depth': [3, 5, 7, 10],
    'min_samples_split': [2, 5, 10]}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)

grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_depth': [3, 5, 7, 10],
#                          'max_features': ['sqrt', 'log2', None],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
## 9. Hyperparameter Results Analysis

re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_depth': 3, 'max_features': None, 'min_samples_split': 2, 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.003275      0.001373         0.004392        0.003030
# 1         0.003554      0.003239         0.002064        0.001311
# 2         0.003244      0.000998         0.003293        0.002539
# 3         0.002463      0.000791         0.002175        0.001319
# 4         0.001739      0.000391         0.003086        0.001481
# ..             ...           ...              ...             ...
# 211       0.002524      0.001040         0.002745        0.000958
# 212       0.003462      0.001255         0.001641        0.001923
# 213       0.002224      0.001168         0.001714        0.000546
# 214       0.002791      0.001539         0.003048        0.001137
# 215       0.001288      0.001066         0.000796        0.000975
#
#     param_criterion  param_max_depth param_max_features  \
# 0     squared_error                3               sqrt
# 1     squared_error                3               sqrt
# 2     squared_error                3               sqrt
# 3     squared_error                3               sqrt
# 4     squared_error                3               sqrt
# ..              ...              ...                ...
# 211    friedman_mse               10               None
# 212    friedman_mse               10               None
# 213    friedman_mse               10               None
# 214    friedman_mse               10               None
# 215    friedman_mse               10               None
#
#      param_min_samples_split param_splitter  \
# 0                          2           best
# 1                          2         random
# 2                          5           best
# 3                          5         random
# 4                         10           best
# ..                       ...            ...
# 211                        2         random
# 212                        5           best
# 213                        5         random
# 214                       10           best
# 215                       10         random
#
#                                                 params  split0_test_score  \
# 0    {'criterion': 'squared_error', 'max_depth': 3,...           0.560331
# 1    {'criterion': 'squared_error', 'max_depth': 3,...           0.558238
# 2    {'criterion': 'squared_error', 'max_depth': 3,...           0.639158
# 3    {'criterion': 'squared_error', 'max_depth': 3,...           0.765416
# 4    {'criterion': 'squared_error', 'max_depth': 3,...           0.764559
# ..                                                 ...                ...
# 211  {'criterion': 'friedman_mse', 'max_depth': 10,...           0.674513
# 212  {'criterion': 'friedman_mse', 'max_depth': 10,...           0.731745
# 213  {'criterion': 'friedman_mse', 'max_depth': 10,...           0.753991
# 214  {'criterion': 'friedman_mse', 'max_depth': 10,...           0.752267
# 215  {'criterion': 'friedman_mse', 'max_depth': 10,...           0.811942
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             0.714981           0.829922           0.421578
# 1             0.590241           0.432452           0.641461
# 2             0.380783           0.806528           0.156486
# 3             0.624468           0.667663           0.291686
# 4             0.683587           0.430178           0.743463
# ..                 ...                ...                ...
# 211           0.757953           0.781399           0.590503
# 212           0.538228           0.796578           0.679054
# 213           0.719833           0.855553           0.797682
# 214           0.617176           0.807280           0.687816
# 215           0.795805           0.816242           0.807825
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.738191         0.653001        0.144599              151
# 1             0.277106         0.499900        0.130989              203
# 2             0.167266         0.430044        0.257597              212
# 3             0.622743         0.594395        0.159973              185
# 4             0.752193         0.674796        0.125442              129
# ..                 ...              ...             ...              ...
# 211           0.668600         0.694593        0.068503              110
# 212           0.706878         0.690496        0.085487              114
# 213           0.742230         0.773858        0.048074               39
# 214           0.729319         0.718772        0.063791               85
# 215           0.714668         0.789296        0.037931               25
#
# [216 rows x 18 columns]

# %%
## 10. Model Evaluation
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

y_pred = grid.predict(x_test) 

r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
mae = mean_absolute_error(y_test, y_pred)
n = x_test.shape[0]  
p = x_test.shape[1]   
adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)

print("R2 Score:", r2)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)
print("Adjusted R2 Score:", adjusted_r2)
# Out:
# R2 Score: 0.8742930260385806
# Mean Squared Error: 20155252.895239018
# Root Mean Squared Error: 4489.460200874824
# Mean Absolute Error: 2761.9734961608874
# Adjusted R2 Score: 0.8728645376981099

# %%
## 11. Visualizing Model Performance
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
best_model = grid.best_estimator_

plot_tree(best_model,feature_names=['age', 'bmi', 'children', 'sex_male', 'smoker_yes'],filled=True)

plt.title("Decision Tree Visualization")
plt.show()

# %%
## 12. Saving the Trained Model and Scaler
best_model = grid.best_estimator_

# Save model
pickle.dump(best_model, open("Finalized_DT_model.sav", "wb"))

# %%
## Conclusion:

#- Implemented Decision Tree Regressor to predict medical insurance costs.
#- Model captures non-linear relationships between features and target effectively.
#- No feature scaling required, making preprocessing simpler compared to SVR.
#- Tends to overfit the training data if not properly controlled (e.g., max_depth).
#- Provides clear interpretability through feature importance.
#- Performance is good but may be less stable compared to ensemble methods like Random Forest.
